# %%
# Has multi-dimensional arrays and matrices.
# Has a large collection of mathematical functions to operate on these arrays.
import numpy as np

# Data manipulation and analysis.
import pandas as pd

# Data visualization tools.
import seaborn as sns

import mesa

# %%
class MoneyAgent(mesa.Agent):
    """An agent with fixed initial wealth."""

    def __init__(self, model):
        # Pass the parameters to the parent class.
        super().__init__(model)

        # Create the agent's variable and set the initial values.
        self.wealth = 1

# %%
class MoneyModel(mesa.Model):
    """A model with some number of agents."""

    def __init__(self, n=10, seed=None):
        super().__init__(seed=seed)
        self.num_agents = n
        # Create agents
        MoneyAgent.create_agents(model=self, n=n)

# %%
class MoneyAgent(mesa.Agent):
    """An agent with fixed initial wealth."""

    def __init__(self, model):
        # Pass the parameters to the parent class.
        super().__init__(model)

        # Create the agent's attribute and set the initial values.
        self.wealth = 1

    def say_hi(self):
        # The agent's step will go here.
        # For demonstration purposes we will print the agent's unique_id
        print(f"Hi, I am an agent, you can call me {self.unique_id!s}.")
        if self.wealth == 0:
            print("Hi, I am an agent and I am broke!")
        else:
            print(f"Hi, I am an agent and I have {self.wealth} money.")

# %%
class MoneyModel(mesa.Model):
    """A model with some number of agents."""

    def __init__(self, n=10, seed=None):
        super().__init__(seed=seed)
        self.num_agents = n

        # Create n agents
        MoneyAgent.create_agents(model=self, n=n)

    def step(self):
        """Advance the model by one step."""
        # This function psuedo-randomly reorders the list of agent objects and
        # then iterates through calling the function passed in as the parameter
        self.agents.shuffle_do("say_hi")

# %%
starter_model = MoneyModel(10)
starter_model.step()
# Out:
# Hi, I am an agent, you can call me 8.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 9.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 3.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 4.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 10.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 2.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 1.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 5.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 6.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent, you can call me 7.
# Hi, I am an agent and I have 1 money.

# %%
# Run this step a few times and see what happens!
starter_model.step()
# Notice the order of the agents changes each time.

# %%
class MoneyAgent(mesa.Agent):
    """An agent with fixed initial wealth."""

    def __init__(self, model):
        # Pass the parameters to the parent class.
        super().__init__(model)

        # Create the agent's variable and set the initial values.
        self.wealth = 1

    def say_wealth(self):
        # The agent's step will go here.
        # FIXME: need to print the agent's wealth
        if self.wealth == 0:
            print("Hi, I am an agent and I am broke!")
        else:
            print(f"Hi, I am an agent and I have {self.wealth} money.")

# %%
class MoneyModel(mesa.Model):
    """A model with some number of agents."""

    def __init__(self, n=10, seed=None):
        super().__init__(seed=seed)
        self.num_agents = n

        # Create n agents
        MoneyAgent.create_agents(model=self, n=n)

    def step(self):
        """Advance the model by one step."""
        # This function psuedo-randomly reorders the list of agent objects and
        # then iterates through calling the function passed in as the parameter
        self.agents.shuffle_do("say_wealth")

# %%
starter_model = MoneyModel(10)
starter_model.step()
# Out:
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.
# Hi, I am an agent and I have 1 money.

# %%
starter_model = MoneyAgent(starter_model)
starter_model.step()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 starter_model = MoneyAgent(starter_model)
#       2 starter_model.step()
#
# Cell In[38], line 6, in MoneyAgent.__init__(self, model)
#       4 def __init__(self, model):
#       5     # Pass the parameters to the parent class.
# ----> 6     super().__init__(model)
#       8     # Create the agent's variable and set the initial values.
#       9     self.wealth = 1
#
# File c:\Users\dangorton\Documents\GitHub\MABS_using_Mesa\.venv\Lib\site-packages\mesa\agent.py:73, in Agent.__init__(self, model, *args, **kwargs)
#      71 self.unique_id = None
#      72 self.pos: Position | None = None
# ---> 73 self.model.register_agent(self)
#      75 for dataset in self._datasets:
#      76     self.model.data_registry[dataset].add_agent(self)
#
# AttributeError: 'MoneyAgent' object has no attribute 'register_agent'
